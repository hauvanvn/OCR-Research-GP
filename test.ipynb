# %%
from testOCR import testOCR

# %%
result = testOCR()
print(result)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result = testOCR()
#       2 print(result)
#
# File d:\Python Env\DATN\DATN_OCR\OCR-Research-GP\testOCR.py:97, in testOCR()
#      94     return {"error": "Unable to read image file — possibly corrupted or unsupported format."}
#      96 h, w, _ = image.shape
# ---> 97 boxes = reader.readtext(image, paragraph=False, width_ths=0.01)
#      99 # Step 1: Collect per-word boxes and text
#     100 results = []
#
# ...
